# %%
import os

asbs = {}
for dirname, dirs, files in os.walk(r"\\city\bentley\ProjectWiseStorage\0000\dms27004"):
    for filename in files:
        filenamestrip = filename.strip('.pdf')
        # join file directory to file to get entire filepath
        filedir = os.path.join(dirname, filename)
        # get the size of the file
        size = os.path.getsize(filedir)
        # fill dict platpaths with filenamestrip as key and list of filedir and
        # size as values
        asbs[filenamestrip] = [filedir, size]

# %%
num_san = {}
num_storm = {}
alpha_san = {}

dicts_tuples = [("S-\d|ABS-\d", num_san), ("ALLEY|D|S-1DR", num_storm), ("ABSD-\d|SD-\d", alpha_san), ("ABSD-[a-zA-Z]|SD-[a-zA-Z]", alpha_storm) ("\d+|S-TUN|[CFHILMNOPW]", tunnel) ("ALLEY|D|S-1DR", drains)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-41ac96a16641> in <module>()
# ----> 1 dicts_tuples = [("S-\d|ABS-\d", num_san), ("ALLEY|D|S-1DR", num_storm), ("ABSD-\d|SD-\d", alpha_san), ("ABSD-[a-zA-Z]|SD-[a-zA-Z]", alpha_storm) ("\d+|S-TUN|[CFHILMNOPW]", tunnel) ("ALLEY|D|S-1DR", drains)]
#
# NameError: name 'num_san' is not defined

# %%
import re



dictionary = {"0570" : 1, "0609": 3, "0678": 4}
lists = ["570", "609", "678"]

patterns = []
for item in lists:
    #pattern = (r"(?<=[0])" + str(item) + "{1}$")
    pattern = ("0" + str(item))# + "{1}$")
    patterns.append(pattern)
for pattern, key in zip(patterns, dictionary.keys()):
    if (re.search(pattern, str(dictionary.keys()))):
        print (dictionary[key])
# Out:
# 1
# 3
# 4

# %%
import re



dictionary = {"00057009" : 1, "006098": 3, "0006789": 4}
lists = ["514", "575", "564", "6"]

patterns = []
for item in lists:
    #pattern = (r"(?<=[0])" + str(item) + "{1}$")
    pattern = ("000" + str(item))# + "{1}$")
    patterns.append(pattern)

for key in asbs.keys():
    for item in patterns:
        pattern = item

        if (re.search(pattern, key)):
            print (key)
            

list of boolean true false for each key, this will then be the main one it runs off
# Out:
# ASB 0006

# %%
# Out:
# {'ASB 0001': ['\\\\city\\bentley\\ProjectWiseStorage\\0000\\dms27004\\ASB 0001.pdf',
#   107784],
#  'ASB 0002': ['\\\\city\\bentley\\ProjectWiseStorage\\0000\\dms27004\\ASB 0002.pdf',
#   93217],
#  'ASB 0003': ['\\\\city\\bentley\\ProjectWiseStorage\\0000\\dms27004\\ASB 0003.pdf',
#   84737],
#  'ASB 0004': ['\\\\city\\bentley\\ProjectWiseStorage\\0000\\dms27004\\ASB 0004.pdf',
#   116944],
#  'ASB 0005-1': ['\\\\city\\bentley\\ProjectWiseStorage\\0000\\dms27004\\ASB 0005-1.pdf',
#   130986],
#  'ASB 0005': ['\\\\city\\bentley\\ProjectWiseStorage\\0000\\dms27004\\ASB 0005.pdf',
#   122558],
#  'ASB 0006': ['\\\\city\\bentley\\ProjectWiseStorage\\0000\\dms27004\\ASB 0006.pdf',
#   109081],
#  'ASB 0007': ['\\\\city\\bentley\\ProjectWiseStorage\\0000\\dms27004\\ASB 0007.pdf',
#   104257],
#  'ASB 0008': ['\\\\city\\bentley\\ProjectWiseStorage\\0000\\dms27004\\ASB 0008.pdf',
#   99691],
#  'ASB 0009': ['\\\\city\\bentley\\ProjectWiseStorage\\0000\\dms27004\\ASB 0009.pdf',
# ...
